# %%
import sys
import pandas as pd
pd.options.display.max_rows = 100
pd.options.display.max_seq_items = 100
pd.options.display.max_columns = 100
import numpy as np
import logging
logging.basicConfig(format='%(asctime)s - %(name)s - %(levelname)s - %(message)s', level= logging.DEBUG)
logger = logging.getLogger("webtraffic")
sys.path.extend('/home/hades/PycharmProjects/TimeSeriesExperiments/')     
from sklearn import preprocessing
import os

# %%
import matplotlib.pyplot as plt
plt.style.use("ggplot")
import seaborn as sns
# %matplotlib inline

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload

# %%
data_path = "/home/hades/Documents/Academics/Data/web_traffic"

# %%
train = pd.read_csv(os.path.join(data_path, "train1_std_clean.csv"))

# %%
# I have already cleaned, and augmented the dataset so i am commenting this out
# I did that to save up on my memory
# train["total_visits"] = train.sum(axis=1, numeric_only = True)
# train_clean = train[~(np.abs(train.total_visits - train.total_visits.mean()) > (3*train.total_visits.std()))].copy()
# outliers_train1 = train[(np.abs(train.total_visits - train.total_visits.mean()) > (3*train.total_visits.std()))].copy()
# import re
# def get_language(page):
#     res = re.search('[a-z][a-z].wikipedia.org',page)
#     if res:
#         return res.group()[0:2]
#     return 'na'

# outliers_train1['lang'] = outliers_train1.Page.map(get_language)

# from collections import Counter

# print(Counter(outliers_train1.lang))
# train_clean.to_csv("/home/hades/Documents/Academics/Data/web_traffic/train1_std_clean.csv", index=False)
# outliers_train1.to_csv("/home/hades/Documents/Academics/Data/web_traffic/train1_outliers.csv", index=False)

# %%
train.head()
# Out:
#                                                 Page  2015-07-01  2015-07-02  \
# 0            2NE1_zh.wikipedia.org_all-access_spider        18.0        11.0
# 1             2PM_zh.wikipedia.org_all-access_spider        11.0        14.0
# 2              3C_zh.wikipedia.org_all-access_spider         1.0         0.0
# 3         4minute_zh.wikipedia.org_all-access_spider        35.0        13.0
# 4  52_Hz_I_Love_You_zh.wikipedia.org_all-access_s...         NaN         NaN
#
#    2015-07-03  2015-07-04  2015-07-05  2015-07-06  2015-07-07  2015-07-08  \
# 0         5.0        13.0        14.0         9.0         9.0        22.0
# 1        15.0        18.0        11.0        13.0        22.0        11.0
# 2         1.0         1.0         0.0         4.0         0.0         3.0
# 3        10.0        94.0         4.0        26.0        14.0         9.0
# 4         NaN         NaN         NaN         NaN         NaN         NaN
#
# ...

# %%
english = train[train.lang=='en']
japanese = train[train.lang=='ja']
german = train[train.lang=='de']
na = train[train.lang=='na']
french = train[train.lang=='fr']
chinese = train[train.lang=='zh']
russian = train[train.lang=='ru']
spanish = train[train.lang=='es']

# %%
# Donald Trump
# Turkey
# Alternative for Germany
# Game of Thrones

# %%
english[english["Page"].str.contains("Donald_Trump")]
# Out:
#                                                     Page  2015-07-01  \
# 8736   Cabinet_of_Donald_Trump_en.wikipedia.org_deskt...         NaN
# 8971    Donald_Trump_en.wikipedia.org_desktop_all-agents     35886.0
# 8972   Donald_Trump,_Jr._en.wikipedia.org_desktop_all...      1636.0
# 8973   Donald_Trump_Jr._en.wikipedia.org_desktop_all-...      2065.0
# 8974   Donald_Trump_presidential_campaign,_2016_en.wi...      3201.0
# 9081   Family_of_Donald_Trump_en.wikipedia.org_deskto...         NaN
# 10137  Presidential_transition_of_Donald_Trump_en.wik...         NaN
# 11371  Inauguration_of_Donald_Trump_en.wikipedia.org_...         NaN
# 11764  Proposed_cabinet_of_Donald_Trump_en.wikipedia....         NaN
# 12960  List_of_Donald_Trump_presidential_campaign_end...         NaN
# 32644  Cabinet_of_Donald_Trump_en.wikipedia.org_all-a...         NaN
# 32870  Donald_Trump,_Jr._en.wikipedia.org_all-access_...        53.0
# 32871  Donald_Trump_presidential_campaign,_2016_en.wi...       156.0
# ...

# %%
df = pd.DataFrame(english.loc[8736][1:english.shape[1]-2])

# %%
df.index = pd.to_datetime(df.index)

# %%
df = df.asfreq(freq="D", method="pad")

# %%
df.head()
# Out:
#            8736
# 2015-07-01  NaN
# 2015-07-02  NaN
# 2015-07-03  NaN
# 2015-07-04  NaN
# 2015-07-05  NaN
